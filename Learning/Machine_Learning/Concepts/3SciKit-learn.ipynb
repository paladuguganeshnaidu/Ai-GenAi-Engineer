# %%
from sklearn.linear_model import LinearRegression

# Create some sample data
X = [[1], [2], [3], [4], [5]]
y = [2, 4, 6, 8, 10]

# Create the model
model = LinearRegression()

# Train the model
model.fit(X, y)

# Predict a value
prediction = model.predict([[6]])

print(prediction)
# Out:
# [12.]

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.tree import DecisionTreeClassifier

data = {
    "Skills": [
        "python", "java", "python", "c++", "python",
        "java", "python", "c++", "python", "java"
    ],
    "Experience": [
        3, 1, 5, 2, 7,
        0, 4, 3, 6, 1
    ],
    "Degree": [
        "btech", "bca", "mtech", "btech", "mtech",
        "bca", "btech", "btech", "mtech", "bca"
    ],
    "Selected": [
        "Yes", "No", "Yes", "No", "Yes",
        "No", "Yes", "No", "Yes", "No"
    ]
}

df = pd.DataFrame(data)

skill_encoder = LabelEncoder()
degree_encoder = LabelEncoder()
target_encoder = LabelEncoder()

df["Skills"] = skill_encoder.fit_transform(df["Skills"])
df["Degree"] = degree_encoder.fit_transform(df["Degree"])
df["Selected"] = target_encoder.fit_transform(df["Selected"])
X = df[["Skills", "Experience", "Degree"]]
y = df["Selected"]

model = DecisionTreeClassifier()

model.fit(X, y)

print("Model Trained Successfully")
# Out:
# Model Trained Successfully

# %%
new_candidate = pd.DataFrame({
    "Skills": ["python"],
    "Experience": [0],
    "Degree": ["btech"]
})

new_candidate["Skills"] = skill_encoder.transform(new_candidate["Skills"])
new_candidate["Degree"] = degree_encoder.transform(new_candidate["Degree"])
print(new_candidate)
prediction = model.predict(new_candidate)

print(target_encoder.inverse_transform(prediction)[0])
# Out:
#    Skills  Experience  Degree
# 0       2           0       1
# Yes

# %%
def predict_candidate(skill, experience, degree):
    candidate = pd.DataFrame({
        "Skills": [skill],
        "Experience": [experience],
        "Degree": [degree]
    })

    candidate["Skills"] = skill_encoder.transform(candidate["Skills"])
    candidate["Degree"] = degree_encoder.transform(candidate["Degree"])

    prediction = model.predict(candidate)

    result = target_encoder.inverse_transform(prediction)
    print(result[0])
print(predict_candidate("python", 5, "btech"))
print(predict_candidate("java", 1, "bca"))
print(predict_candidate("python", 10, "mtech"))
print(predict_candidate("c++", 2, "btech"))
"""Skill=input("Enter your Skill: ")
Experience=input("Enter Experince: ")
Degree=input("Enter Degree: ")
Skill=Skill.lower()
Experience=Experience.lower()
Degree=Degree.lower()
predict_candidate(Skill,Experience,Degree)"""
# Out:
# Yes
# None
# No
# None
# Yes
# None
# No
# None
# 'Skill=input("Enter your Skill: ")\nExperience=input("Enter Experince: ")\nDegree=input("Enter Degree: ")\nSkill=Skill.lower()\nExperience=Experience.lower()\nDegree=Degree.lower()\npredict_candidate(Skill,Experience,Degree)'

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.tree import DecisionTreeClassifier

DATA_FILE = "Data/Raw/candidates.csv"
df = pd.read_csv(DATA_FILE)

skill_encoder = LabelEncoder()
degree_encoder = LabelEncoder()
target_encoder = LabelEncoder()

df["Skills"] = skill_encoder.fit_transform(df["Skills"])
df["Degree"] = degree_encoder.fit_transform(df["Degree"])
df["Selected"] = target_encoder.fit_transform(df["Selected"])

X = df[["Skills", "Experience", "Degree"]]
y = df["Selected"]

model = DecisionTreeClassifier()

model.fit(X, y)

print("Model Trained Successfully")
# Out:
# Model Trained Successfully

# %%
import pandas as pd
DATA_FILE = "Data/Raw/test_candidates.csv"
df = pd.read_csv(DATA_FILE)
print("number of candidates: ",df.shape[0])
print("number of features: ",df.shape[1])
print("Columns present in the given data: ",*df.columns)
print(df.info())
print(df.describe())
# Out:
# number of candidates:  10000
# number of features:  28
# Columns present in the given data:  Name Degree Branch CollegeTier Experience Python Java C++ SQL TensorFlow PyTorch Docker Git Linux DSA Communication ProblemSolving Internships Certifications Hackathons Projects CGPA Aptitude InterviewScore LeetCodeSolved ExpectedSalaryLPA NoticePeriodDays Selected
# <class 'pandas.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 28 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               10000 non-null  str
#  1   Degree             10000 non-null  str
#  2   Branch             10000 non-null  str
#  3   CollegeTier        10000 non-null  int64
#  4   Experience         10000 non-null  int64
#  5   Python             10000 non-null  int64
#  6   Java               10000 non-null  int64
#  7   C++                10000 non-null  int64
#  8   SQL                10000 non-null  int64
#  9   TensorFlow         10000 non-null  int64
#  10  PyTorch            10000 non-null  int64
#  11  Docker             10000 non-null  int64
#  12  Git                10000 non-null  int64
#  13  Linux              10000 non-null  int64
#  14  DSA                10000 non-null  int64
#  15  Communication      10000 non-null  int64
#  16  ProblemSolving     10000 non-null  int64
#  17  Internships        10000 non-null  int64
#  18  Certifications     10000 non-null  int64
#  19  Hackathons         10000 non-null  int64
#  20  Projects           10000 non-null  int64
#  21  CGPA               10000 non-null  float64
#  22  Aptitude           10000 non-null  int64
#  23  InterviewScore     10000 non-null  int64
#  24  LeetCodeSolved     10000 non-null  int64
#  25  ExpectedSalaryLPA  10000 non-null  float64
#  26  NoticePeriodDays   10000 non-null  int64
#  27  Selected           10000 non-null  str
# dtypes: float64(2), int64(22), str(4)
# memory usage: 2.1 MB
# None
#         CollegeTier    Experience        Python          Java           C++  \
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean       2.277500      3.960600      0.649100      0.500400      0.410600
# std        0.748031      2.574473      0.477276      0.500025      0.491967
# min        1.000000      0.000000      0.000000      0.000000      0.000000
# 25%        2.000000      2.000000      0.000000      0.000000      0.000000
# 50%        2.000000      4.000000      1.000000      1.000000      0.000000
# 75%        3.000000      6.000000      1.000000      1.000000      1.000000
# max        3.000000      8.000000      1.000000      1.000000      1.000000
#
#                 SQL    TensorFlow       PyTorch        Docker           Git  \
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean       0.550800      0.306500      0.307700      0.403400      0.654500
# std        0.497438      0.461063      0.461565      0.490604      0.475555
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      0.000000      0.000000
# 50%        1.000000      0.000000      0.000000      0.000000      1.000000
# 75%        1.000000      1.000000      1.000000      1.000000      1.000000
# max        1.000000      1.000000      1.000000      1.000000      1.000000
#
#        ...   Internships  Certifications    Hackathons      Projects  \
# count  ...  10000.000000    10000.000000  10000.000000  10000.000000
# mean   ...      1.619700        6.018900      4.972100      5.125300
# std    ...      1.421293        3.763955      3.158974      2.979948
# min    ...      0.000000        0.000000      0.000000      0.000000
# 25%    ...      0.000000        3.000000      2.000000      3.000000
# 50%    ...      1.000000        6.000000      5.000000      5.000000
# 75%    ...      3.000000        9.000000      8.000000      7.000000
# max    ...      5.000000       12.000000     10.000000     15.000000
#
#                CGPA      Aptitude  InterviewScore  LeetCodeSolved  \
# count  10000.000000  10000.000000    10000.000000    10000.000000
# mean       7.723910     65.227300       59.616300      277.555500
# std        1.288779     20.624092       23.539029      144.081778
# min        5.500000     30.000000       20.000000        0.000000
# 25%        6.590000     47.000000       39.000000      168.000000
# 50%        7.720000     65.000000       59.000000      276.000000
# 75%        8.840000     83.000000       80.000000      383.000000
# max        9.950000    100.000000      100.000000      740.000000
#
#        ExpectedSalaryLPA  NoticePeriodDays
# count       10000.000000      10000.000000
# mean           15.434650         39.936000
# std             7.232247         29.799156
# min             3.000000          0.000000
# 25%             9.200000         15.000000
# 50%            15.500000         30.000000
# 75%            21.700000         60.000000
# max            28.000000         90.000000
#
# [8 rows x 24 columns]

# %%
import pandas as pd
DATA_FILE = "Data/Raw/test_candidates.csv"
df = pd.read_csv(DATA_FILE)
print(df["Name"].unique())
# Out:
# <StringArray>
# [      'Tejas Gowda X100001',        'Rakesh Das X100002',
#        'Aarav Joshi X100003',      'Deepak Naidu X100004',
#         'Sai Saxena X100005',    'Riya Chowdhury X100006',
#      'Lakshmi Reddy X100007',       'Riya Saxena X100008',
#  'Abhishek Malhotra X100009',   'Sneha Chowdhury X100010',
#  ...
#         'Kavya Iyer X109991',       'Rahul Gowda X109992',
#       'Farhan Kumar X109993',        'Vivaan Rao X109994',
#        'Kavya Patel X109995',       'Reshma Iyer X109996',
#        'Varun Singh X109997',        'Yash Yadav X109998',
#        'Aarav Gupta X109999',      'Anjali Yadav X110000']
# Length: 10000, dtype: str

# %%
import pandas as pd
DATA_FILE = "Data/Raw/test_candidates.csv"
df = pd.read_csv(DATA_FILE)
print(df["Degree"].value_counts())
print(df["Python"].value_counts())
print(df.isnull().sum())
missing_degree = df[df["Selected"].isnull()]
print(missing_degree)
print(df.isnull().sum())
print(df["Degree"].isnull())
# Out:
# Degree
# BTech    3809
# BE       1853
# MCA      1262
# BCA      1158
# MSc       986
# MTech     932
# Name: count, dtype: int64
# Python
# 1    6491
# 0    3509
# Name: count, dtype: int64
# Name                 0
# Degree               0
# Branch               0
# CollegeTier          0
# Experience           0
# Python               0
# Java                 0
# C++                  0
# SQL                  0
# TensorFlow           0
# PyTorch              0
# Docker               0
# Git                  0
# Linux                0
# DSA                  0
# Communication        0
# ProblemSolving       0
# Internships          0
# Certifications       0
# Hackathons           0
# Projects             0
# CGPA                 0
# Aptitude             0
# InterviewScore       0
# LeetCodeSolved       0
# ExpectedSalaryLPA    0
# NoticePeriodDays     0
# Selected             0
# dtype: int64
# Empty DataFrame
# Columns: [Name, Degree, Branch, CollegeTier, Experience, Python, Java, C++, SQL, TensorFlow, PyTorch, Docker, Git, Linux, DSA, Communication, ProblemSolving, Internships, Certifications, Hackathons, Projects, CGPA, Aptitude, InterviewScore, LeetCodeSolved, ExpectedSalaryLPA, NoticePeriodDays, Selected]
# Index: []
#
# [0 rows x 28 columns]
# Name                 0
# Degree               0
# Branch               0
# CollegeTier          0
# Experience           0
# Python               0
# Java                 0
# C++                  0
# SQL                  0
# TensorFlow           0
# PyTorch              0
# Docker               0
# Git                  0
# Linux                0
# DSA                  0
# Communication        0
# ProblemSolving       0
# Internships          0
# Certifications       0
# Hackathons           0
# Projects             0
# CGPA                 0
# Aptitude             0
# InterviewScore       0
# LeetCodeSolved       0
# ExpectedSalaryLPA    0
# NoticePeriodDays     0
# Selected             0
# dtype: int64
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9995    False
# 9996    False
# 9997    False
# 9998    False
# 9999    False
# Name: Degree, Length: 10000, dtype: bool

# %%
import pandas as pd
DATA_FILE = "Data/Raw/test_candidates.csv"
df = pd.read_csv(DATA_FILE)
print(df[df["Selected"].isnull()])
df=df.dropna()
print(df.info)
# Out:
#                     Name Degree Branch  CollegeTier  Experience  Python  Java  \
# 6  Lakshmi Reddy X100007     BE      2            6           1       1     0
#
#    C++  SQL  TensorFlow  ...  Certifications  Hackathons  Projects  CGPA  \
# 6    1    0           0  ...               6           7      5.69  49.0
#
#    Aptitude  InterviewScore  LeetCodeSolved  ExpectedSalaryLPA  \
# 6        51             472            20.0               60.0
#
#    NoticePeriodDays  Selected
# 6               Yes       NaN
#
# [1 rows x 28 columns]
# <bound method DataFrame.info of                       Name Degree Branch  CollegeTier  Experience  Python  \
# 0      Tejas Gowda X100001     BE    EEE            3           7       0
# 1       Rakesh Das X100002    MCA    CSE            3           7       0
# 2      Aarav Joshi X100003  BTech    CSE            1           8       1
# 3     Deepak Naidu X100004  MTech    CSE            3           3       1
# 4       Sai Saxena X100005     BE    CSE            3           8       1
# ...                    ...    ...    ...          ...         ...     ...
# 9995   Reshma Iyer X109996  BTech    ECE            1           3       0
# 9996   Varun Singh X109997  BTech    CSE            2           3       0
# 9997    Yash Yadav X109998  MTech     ME            3           3       1
# 9998   Aarav Gupta X109999     BE    EEE            3           5       1
# 9999  Anjali Yadav X110000  BTech    ISE            2           1       1
#
#       Java  C++  SQL  TensorFlow  ...  Certifications  Hackathons  Projects  \
# 0        1    0    1           0  ...               7           7       8.0
# 1        1    0    1           0  ...              12           2       8.0
# 2        0    0    1           1  ...               5           2       6.0
# 3        1    1    1           1  ...               0           8       4.0
# 4        0    0    1           0  ...               3           2      11.0
# ...    ...  ...  ...         ...  ...             ...         ...       ...
# 9995     0    1    0           0  ...              12          10       8.0
# 9996     0    0    1           0  ...               6           8       3.0
# 9997     0    0    0           1  ...               4          10       4.0
# 9998     1    1    0           1  ...               6          10       8.0
# 9999     0    0    1           1  ...              11           9       4.0
#
#       CGPA  Aptitude  InterviewScore  LeetCodeSolved  ExpectedSalaryLPA  \
# 0     5.69        49              36           468.0               27.9
# 1     8.33        70              22           463.0               10.8
# 2     8.00        52              54           509.0               16.2
# 3     7.79        51              72           173.0                3.5
# 4     7.52        33              81           568.0               23.7
# ...    ...       ...             ...             ...                ...
# 9995  7.15        70              92           232.0               18.3
# 9996  7.56        39              39             5.0               15.4
# 9997  6.08        83              80           250.0               15.2
# 9998  5.59        31              96           381.0               16.2
# 9999  9.08        62              41             0.0               15.1
#
#       NoticePeriodDays  Selected
# 0                   60       Yes
# 1                   30       Yes
# 2                   15       Yes
# 3                   60       Yes
# 4                   45       Yes
# ...                ...       ...
# 9995                45       Yes
# 9996                60       Yes
# 9997                30       Yes
# 9998                60       Yes
# 9999                60       Yes
#
# [9999 rows x 28 columns]>

# %%
import pandas as pd
DATA_FILE = "Data/Raw/test_candidates.csv"
df = pd.read_csv(DATA_FILE)
print(df.isnull().sum())
print(df[df["Branch"].isnull()])
# Out:
# Name                 0
# Degree               0
# Branch               1
# CollegeTier          0
# Experience           0
# Python               0
# Java                 0
# C++                  0
# SQL                  0
# TensorFlow           0
# PyTorch              0
# Docker               0
# Git                  0
# Linux                0
# DSA                  0
# Communication        0
# ProblemSolving       0
# Internships          0
# Certifications       0
# Hackathons           0
# Projects             0
# CGPA                 0
# Aptitude             0
# InterviewScore       0
# LeetCodeSolved       0
# ExpectedSalaryLPA    0
# NoticePeriodDays     0
# Selected             0
# dtype: int64
#                     Name Degree Branch  CollegeTier  Experience  Python  Java  \
# 6  Lakshmi Reddy X100007     BE    NaN            2           6       1     1
#
#    C++  SQL  TensorFlow  ...  Certifications  Hackathons  Projects  CGPA  \
# 6    0    1           0  ...               5           6         7  5.69
#
#    Aptitude  InterviewScore  LeetCodeSolved  ExpectedSalaryLPA  \
# 6        49              51             472               20.0
#
#    NoticePeriodDays  Selected
# 6                60       Yes
#
# [1 rows x 28 columns]

# %%
import pandas as pd
from sklearn.impute import SimpleImputer
DATA_FILE = "Data/Raw/test_candidates.csv"
df = pd.read_csv(DATA_FILE)
print(df.isnull().sum())
print(df[df["InterviewScore"].isnull()])
imputer=SimpleImputer(strategy="mean")
df[["InterviewScore"]]=imputer.fit_transform(df[["InterviewScore"]])
print(df[df["Name"].str.contains("X100001")])
# Out:
# Name                 0
# Degree               0
# Branch               0
# CollegeTier          0
# Experience           0
# Python               0
# Java                 0
# C++                  0
# SQL                  0
# TensorFlow           0
# PyTorch              0
# Docker               0
# Git                  0
# Linux                0
# DSA                  0
# Communication        0
# ProblemSolving       0
# Internships          0
# Certifications       0
# Hackathons           0
# Projects             0
# CGPA                 0
# Aptitude             0
# InterviewScore       1
# LeetCodeSolved       0
# ExpectedSalaryLPA    0
# NoticePeriodDays     0
# Selected             0
# dtype: int64
#                  Name Degree Branch  CollegeTier  Experience  Python  Java  \
# 1  Rakesh Das X100002    MCA    CSE            3           7       0     1
#
#    C++  SQL  TensorFlow  ...  Certifications  Hackathons  Projects  CGPA  \
# 1    0    1           0  ...              12           2         8  8.33
#
#    Aptitude  InterviewScore  LeetCodeSolved  ExpectedSalaryLPA  \
# 1        70             NaN             463               10.8
#
#    NoticePeriodDays  Selected
# 1                30       Yes
#
# [1 rows x 28 columns]
#                   Name Degree Branch  CollegeTier  Experience  Python  Java  \
# 0  Tejas Gowda X100001     BE    EEE            3           7       0     1
#
#    C++  SQL  TensorFlow  ...  Certifications  Hackathons  Projects  CGPA  \
# 0    0    1           0  ...               7           7         8  5.69
#
#    Aptitude  InterviewScore  LeetCodeSolved  ExpectedSalaryLPA  \
# 0        49            36.0             468               27.9
#
#    NoticePeriodDays  Selected
# 0                60       Yes
#
# [1 rows x 28 columns]

# %%
import requests
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans

API_KEY = "1f0349cbd2cf40dc941afcb15911976c"

url = f"https://newsapi.org/v2/top-headlines?country=us&pageSize=20&apiKey={API_KEY}"

response = requests.get(url)
data = response.json()

if data.get("status") != "ok":
    print(data)
    exit()

headlines = [article["title"] for article in data["articles"] if article["title"]]

X = TfidfVectorizer(stop_words="english").fit_transform(headlines)

kmeans = KMeans(n_clusters=4, random_state=42, n_init="auto")
labels = kmeans.fit_predict(X)

df = pd.DataFrame({
    "Headline": headlines,
    "Cluster": labels
})

print(df.sort_values("Cluster"))
# Out:
#                                              Headline  Cluster
# 3   SpaceX stock now enters the post-honeymoon fai...        0
# 6   World Cup quarterfinals bracket: Full schedule...        0
# 10  Belgian prime minister suggests US World Cup l...        0
# 9   World Cup Daily live: Argentina, Messi produce...        0
# 7   Ex-girlfriend of Graham Platner says he remove...        1
# 4   Dallas Cowboys player Marshawn Kneeland who di...        1
# 1   NATO allies temper expectations for summit aft...        1
# 0   U.S. strikes Iran after attacks on vessels in ...        1
# 12  ‘Big Brother’ Season 28 Cast Revealed: ‘RuPaul...        1
# 13  Fans Canceling PS Plus To Boycott Sony Killing...        1
# 8   First locally acquired Chagas infection confir...        1
# 11  Cyclosporiasis outbreaks: What to know about t...        1
# 15  DeSantis-backed 'Stop WOKE' law meets appeals ...        1
# 16  Everything We Know About the Food Served at Ta...        1
# 17  New footage shown at Charlie Kirk hearing show...        1
# 2   Meta & Ray-Ban glasses rolling out mandatory u...        2
# 14  James Webb Space Telescope celebrates its 4th ...        3
# 5   Samsung confirms Galaxy Unpacked event, with t...        3
