# %%
import tiktoken
sen="so seee, i gave you two plan to learn paralley together called track A & B, Yesterday we saw some long things in my planning, so let us make strong plan which make me poweful at the end of my time decoed , so alalyze all the computed and real learned things and mark it as completed, make a strong plan in md fomat to copy"
tokenizer=tiktoken.encoding_for_model(model_name="gpt-4o")
tokenids=tokenizer.encode(sen)
print(f"""
total tokens: {len(tokenids)}
Sentence: {sen}
tokenids: {tokenids}
""")
# Out:
# total tokens: 77
# Sentence: so seee, i gave you two plan to learn paralley together called track A & B, Yesterday we saw some long things in my planning, so let us make strong plan which make me poweful at the end of my time decoed , so alalyze all the computed and real learned things and mark it as completed, make a strong plan in md fomat to copy
# tokenids: [786, 1921, 68, 11, 575, 10175, 481, 1920, 3496, 316, 4484, 46037, 4356, 4717, 4358, 5290, 355, 827, 418, 11, 85247, 581, 8274, 1236, 1701, 3283, 306, 922, 10249, 11, 813, 1632, 765, 1520, 5532, 3496, 1118, 1520, 668, 9779, 1079, 361, 540, 290, 1268, 328, 922, 1058, 135713, 295, 1366, 813, 434, 71553, 722, 290, 46716, 326, 1374, 13717, 3283, 326, 1983, 480, 472, 11121, 11, 1520, 261, 5532, 3496, 306, 17280, 285, 63584, 316, 5150]
